# %%
# Use the native inference API to send a text message to Amazon Titan Text G1 - Express.

import boto3
import json

from botocore.exceptions import ClientError

# Create an Amazon Bedrock Runtime client.
brt = boto3.client("bedrock-runtime")

# Set the model ID, e.g., Amazon Titan Text G1 - Express.
model_id = "amazon.titan-text-express-v1"

# Define the prompt for the model.
# Ask user for input
prompt = input("Enter your prompt for the Amazon Titan Text model: ")


# Format the request payload using the model's native structure.
native_request = {
    "inputText": prompt,
    "textGenerationConfig": {
        "maxTokenCount": 512,
        "temperature": 0.5,
        "topP": 0.9
    },
}

# Convert the native request to JSON.
request = json.dumps(native_request)

try:
    # Invoke the model with the request.
    response = brt.invoke_model(modelId=model_id, body=request)

except (ClientError, Exception) as e:
    print(f"ERROR: Can't invoke '{model_id}'. Reason: {e}")
    exit(1)

# Decode the response body.
model_response = json.loads(response["body"].read())

# Extract and print the response text.
response_text = model_response["results"][0]["outputText"]
print(response_text)
# Out:
# Agent is a software program that can be used to automate tasks or provide information and support to users. Agent can be used in a variety of settings, including customer service, healthcare, and manufacturing.
#
# One of the key features of an agent is its ability to understand natural language. This allows the agent to communicate with users in a way that is easy to understand and respond to their questions or requests. Agents can also be trained to handle a wide range of tasks, including scheduling appointments, processing orders, and providing technical support.
#
# Agents can be implemented in a variety of ways, including web-based applications, mobile apps, and desktop applications. Web-based agents are typically accessed through a web browser, while mobile apps can be downloaded to a smartphone or tablet. Desktop applications can be installed on a computer.
#
# Agents can be powered by a variety of technologies, including artificial intelligence (AI), machine learning (ML), and natural language processing (NLP). AI is a technology that allows computers to learn from data and make decisions based on that data. ML is a technology that allows computers to learn from data and improve their performance over time. NLP is a technology that allows computers to understand and interpret human language.
#
# Agents can be used to improve customer service by providing faster and more accurate responses to customer questions or requests. Agents can also be used to automate tasks that are repetitive or time-consuming, such as scheduling appointments or processing orders. Agents can also be used to provide support to users who are experiencing technical problems.
#
# However, there are also some challenges associated with agents. One of the biggest challenges is ensuring that agents are accurate and reliable. Agents can make mistakes if they are not trained properly or if they are not given the right information. Agents can also be vulnerable to security breaches if they are not properly secured.
#
# To address these challenges, it is important to develop and implement effective agent management strategies. Agent management strategies include training agents, monitoring agents, and managing agent performance. Training agents involves providing agents with the necessary training and resources to perform their tasks effectively. Monitoring agents involves monitoring agents to ensure that they are performing their tasks effectively and that they are not making mistakes. Managing agent performance involves evaluating agent performance and making adjustments as needed.
#
# In addition to agent management strategies, it is also important to ensure that agents are integrated with other systems and technologies. Agents can be integrated with customer relationship management (CRM) systems, order management systems, and inventory management systems. This allows agents to access

# %%
# Copyright Amazon.com, Inc. or its affiliates. All Rights Reserved.
# SPDX-License-Identifier: Apache-2.0

# snippet-start:[python.example_code.bedrock-runtime.ConverseStream_MetaLlama]
# Use the Conversation API to send a text message to Meta Llama
# and print the response stream.

import boto3
from botocore.exceptions import ClientError

# Create a Bedrock Runtime client in the AWS Region you want to use.
client = boto3.client("bedrock-runtime", region_name="us-east-1")

# Set the model ID, e.g., Llama 3 8b Instruct.
model_id = "meta.llama3-70b-instruct-v1:0"

# Start a conversation with the user message.
user_message = "Describe the purpose of a 'hello world' program in one line."
conversation = [
    {
        "role": "user",
        "content": [{"text": user_message}],
    }
]

try:
    # Send the message to the model, using a basic inference configuration.
    streaming_response = client.converse_stream(
        modelId=model_id,
        messages=conversation,
        inferenceConfig={"maxTokens": 512, "temperature": 0.5, "topP": 0.9},
    )

    # Extract and print the streamed response text in real-time.
    for chunk in streaming_response["stream"]:
        if "contentBlockDelta" in chunk:
            text = chunk["contentBlockDelta"]["delta"]["text"]
            print(text, end="")

except (ClientError, Exception) as e:
    print(f"ERROR: Can't invoke '{model_id}'. Reason: {e}")
    exit(1)

# snippet-end:[python.example_code.bedrock-runtime.ConverseStream_MetaLlama]
# Out:
# The purpose of a "Hello World" program is to provide a simple and introductory example of a programming language's syntax and functionality, typically used to verify that a development environment is set up correctly and to introduce beginners to the basics of coding.
